# %%
import os
os.environ["LANGCHAIN_TRACING"] = "true" # If you want to trace the execution of the program, set to "true"

from dotenv import load_dotenv
load_dotenv()

from langchain.agents import AgentType
from langchain.chat_models import ChatOpenAI
from langchain.agents import initialize_agent

from langchain.agents.agent_toolkits import PlayWrightBrowserToolkit
from langchain.tools.playwright.utils import (
    create_async_playwright_browser,
    create_sync_playwright_browser, # A synchronous browser is available, though it isn't compatible with jupyter.
)

# This import is required only for jupyter notebooks, since they have their own eventloop
import nest_asyncio
nest_asyncio.apply()

async_browser = create_async_playwright_browser()
browser_toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = browser_toolkit.get_tools()

llm = ChatOpenAI(temperature=0) # Also works well with Anthropic models
agent_chain = initialize_agent(tools, llm, agent=AgentType.STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %%
response = await agent_chain.arun(input="I want to look for orchestra jobs for violin, find me some in the US and give me a summary of them ")
print(response)
# Out:
# WARNING:root:Failed to load default session, using empty session: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /sessions?name=default (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x105f07a00>: Failed to establish a new connection: [Errno 61] Connection refused'))
# > Entering new  chain...
# WARNING:root:Failed to load default session, using empty session: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /sessions?name=default (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x174595840>: Failed to establish a new connection: [Errno 61] Connection refused'))
# WARNING:root:Failed to persist run: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /chain-runs (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x174596a40>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Thought: To find orchestra jobs for violin in the US, I can search for websites that list job postings for musicians. Then, I can extract the relevant information from the job listings to provide a summary.
#
# Action:
# ```
# {
#   "action": "navigate_browser",
#   "action_input": {
#     "url": "https://www.musicalchairs.info/violin/jobs"
#   }
# }
# ```
# Observation: Navigating to https://www.musicalchairs.info/violin/jobs returned status code 200
# Thought:I have successfully navigated to the website that lists violin jobs. Now I will extract the relevant information from the job listings.
#
# Action:
# ```
# {
#   "action": "extract_text",
#   "action_input": {}
# }
# ```
# Observation: Violin Jobs | Violin Auditions | Violin Employment Positions Search Login Publish with us We are the world's leading online resource for classical music professionals and students Sections Postings: More Performance Jobs Teaching Jobs Admin Jobs Courses Competitions Instrument Sales Stolen Instruments More Directories: Orchestras & Opera Houses Conservatoires Youth Orchestras musicalchairs: About Us Contact Us Twitter Feeds RSS Feeds Classical Music News Publishers: Publish with us Login Violin Performance Jobs (77) Related content Sort posts by Violin Teaching Jobs (15) Violin Courses/ Masterclass (67) Violin Competitions (49) All Violin Sales (43) Stolen Violins (171) • Posted Date • Closing Date • country (a-z) Evansville, IN, United States Posted: 30 Jun 2023 Evansville Philharmonic Orchestra Assistant Concertmaster/ Section 1 Violin (per service) Closing date: 15 Aug 2023 Paris, France Posted: 30 Jun 2023 Orchestre Lamoureux 1 Premier violon, 2ème soliste + 3 violons du rang (tutti) Closing date: 04 Sep 2023 Cardiff, United Kingdom Posted: 30 Jun 2023 Welsh National Opera Violin Extra Work (Tutti / Numbered as required) (extra work / substitutes) Closing date: 09 Aug 2023 Tulsa Philharmonic, OK, United States Posted: 30 Jun 2023 Tulsa Symphony Orchestra Principal and Associate Principal Second Violin (per service) Closing date: 16 Aug 2023 St. Louis, MO, United States Posted: 29 Jun 2023 St. Louis Symphony Orchestra Section First Violin (3 Positions) Closing date: 31 Jul 2023 Brussels, Belgium Posted: 29 Jun 2023 De Munt, La Monnaie Associate Concertmaster Closing date: 27 Aug 2023 Ottawa, ON, Canada Posted: 29 Jun 2023 National Arts Centre / Centre national des Arts Section Violin Closing date: 31 Aug 2023 New York, NY, United States Posted: 29 Jun 2023 Lincoln Center Stage/ Holland America Line Lincoln Center Stage/ Holland America Line (short-term) Closing date: 07 Jul 2023 Springfield, MO, United States Posted: 28 Jun 2023 Springfield MO Symphony Springfield MO Symphony Orchestra - violin positions (per service) Closing date: 25 Aug 2023 Auckland, New Zealand Posted: 28 Jun 2023 Auckland Philharmonia Orchestra Rotating Tutti Violin Closing date: 30 Jul 2023 Charleston, SC, United States Posted: 28 Jun 2023 Charleston Symphony Orchestra Violin Inclusion Fellowship (1 position) (per service) Closing date: 14 Jul 2023 Genève, Switzerland Posted: 27 Jun 2023 Orchestre de la Suisse Romande Violon tuttiste - registre des seconds violons | Tutti second violin (2) – Permanent Closing date: 27 Aug 2023 Antwerp, Belgium Posted: 27 Jun 2023 Antwerp Symphony Orchestra Associate Concertmaster (2nd/ 3rd/ 4th chair) Closing date: 09 Oct 2023 Oslo, Norway Posted: 27 Jun 2023 Norwegian Radio Orchestra 1st Concertmaster, 50% position. Norwegian Radio Orchestra (part-time) Closing date: 21 Aug 2023 Bolling AFB, DC, United States Posted: 27 Jun 2023 United States Air Force Band Violin Closing date: 31 Aug 2023 York, PA, United States Posted: 27 Jun 2023 York Symphony Orchestra Assistant Principal Violin II & Section Violin I (3 Positions Total) (per service) Closing date: 21 Sep 2023 Kuopio, Finland Posted: 26 Jun 2023 Kuopio Symphony Orchestra Associate Concertmaster (substitute) and II Violin Principal  (substitute) Closing date: 31 Jul 2023 Kuopio, Finland Posted: 26 Jun 2023 Kuopio Symphony Orchestra I Violin Principal Closing date: 17 Jul 2023 Kuopio, Finland Posted: 26 Jun 2023 Kuopio Symphony Orchestra I Violin Tutti and II Violin Tutti and II Violin Tutti (substitute) Closing date: 17 Jul 2023 Norrköping, Sweden Posted: 23 Jun 2023 Norrköping Symphony Orchestra Violin 2 tutti (1) 100% Closing date: 03 Sep 2023 Clermont Ferrand, France Posted: 23 Jun 2023 Orchestre national Auvergne-Rhône-Alpes 3 Violons tutti Closing date: 17 Sep 2023 London, United Kingdom Posted: 22 Jun 2023 Royal Philharmonic Orchestra First Violin No. 7 & No. 13 (Tutti) Closing date: 07 Aug 2023 Québec, QC, Canada Posted: 22 Jun 2023 Orchestre sy ...
# Thought:
# WARNING:root:Failed to persist run: HTTPConnectionPool(host='localhost', port=8000): Max retries exceeded with url: /chain-runs (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x28128a7a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = await agent_chain.arun(input="I want to look for orchestra jobs for violin, find me some in the US and give me a summary of them ")
#       2 print(response)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/base.py:328, in Chain.arun(self, callbacks, tags, *args, **kwargs)
#     323     return (await self.acall(args[0], callbacks=callbacks, tags=tags))[
#     324         self.output_keys[0]
#     325     ]
#     327 if kwargs and not args:
# --> 328     return (await self.acall(kwargs, callbacks=callbacks, tags=tags))[
#     329         self.output_keys[0]
#     330     ]
#     332 raise ValueError(
#     333     f"`run` supported with either positional arguments or keyword arguments"
#     334     f" but not both. Got args: {args} and kwargs: {kwargs}."
#     335 )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/base.py:215, in Chain.acall(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     213 except (KeyboardInterrupt, Exception) as e:
#     214     await run_manager.on_chain_error(e)
# --> 215     raise e
#     216 await run_manager.on_chain_end(outputs)
#     217 final_outputs: Dict[str, Any] = self.prep_outputs(
#     218     inputs, outputs, return_only_outputs
#     219 )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/base.py:209, in Chain.acall(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     203 run_manager = await callback_manager.on_chain_start(
#     204     dumpd(self),
#     205     inputs,
#     206 )
#     207 try:
#     208     outputs = (
# --> 209         await self._acall(inputs, run_manager=run_manager)
#     210         if new_arg_supported
#     211         else await self._acall(inputs)
#     212     )
#     213 except (KeyboardInterrupt, Exception) as e:
#     214     await run_manager.on_chain_error(e)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/agents/agent.py:1036, in AgentExecutor._acall(self, inputs, run_manager)
#    1034 try:
#    1035     while self._should_continue(iterations, time_elapsed):
# -> 1036         next_step_output = await self._atake_next_step(
#    1037             name_to_tool_map,
#    1038             color_mapping,
#    1039             inputs,
#    1040             intermediate_steps,
#    1041             run_manager=run_manager,
#    1042         )
#    1043         if isinstance(next_step_output, AgentFinish):
#    1044             return await self._areturn(
#    1045                 next_step_output,
#    1046                 intermediate_steps,
#    1047                 run_manager=run_manager,
#    1048             )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/agents/agent.py:883, in AgentExecutor._atake_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     877 """Take a single step in the thought-action-observation loop.
#     878
#     879 Override this to take control of how the agent makes and acts on choices.
#     880 """
#     881 try:
#     882     # Call the LLM to see what to do.
# --> 883     output = await self.agent.aplan(
#     884         intermediate_steps,
#     885         callbacks=run_manager.get_child() if run_manager else None,
#     886         **inputs,
#     887     )
#     888 except OutputParserException as e:
#     889     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/agents/agent.py:464, in Agent.aplan(self, intermediate_steps, callbacks, **kwargs)
#     452 """Given input, decided what to do.
#     453
#     454 Args:
#    (...)
#     461     Action specifying what tool to use.
#     462 """
#     463 full_inputs = self.get_full_inputs(intermediate_steps, **kwargs)
# --> 464 full_output = await self.llm_chain.apredict(callbacks=callbacks, **full_inputs)
#     465 return self.output_parser.parse(full_output)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/llm.py:269, in LLMChain.apredict(self, callbacks, **kwargs)
#     254 async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     255     """Format prompt with kwargs and pass to LLM.
#     256
#     257     Args:
#    (...)
#     267             completion = llm.predict(adjective="funny")
#     268     """
# --> 269     return (await self.acall(kwargs, callbacks=callbacks))[self.output_key]
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/base.py:215, in Chain.acall(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     213 except (KeyboardInterrupt, Exception) as e:
#     214     await run_manager.on_chain_error(e)
# --> 215     raise e
#     216 await run_manager.on_chain_end(outputs)
#     217 final_outputs: Dict[str, Any] = self.prep_outputs(
#     218     inputs, outputs, return_only_outputs
#     219 )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/base.py:209, in Chain.acall(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     203 run_manager = await callback_manager.on_chain_start(
#     204     dumpd(self),
#     205     inputs,
#     206 )
#     207 try:
#     208     outputs = (
# --> 209         await self._acall(inputs, run_manager=run_manager)
#     210         if new_arg_supported
#     211         else await self._acall(inputs)
#     212     )
#     213 except (KeyboardInterrupt, Exception) as e:
#     214     await run_manager.on_chain_error(e)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/llm.py:234, in LLMChain._acall(self, inputs, run_manager)
#     229 async def _acall(
#     230     self,
#     231     inputs: Dict[str, Any],
#     232     run_manager: Optional[AsyncCallbackManagerForChainRun] = None,
#     233 ) -> Dict[str, str]:
# --> 234     response = await self.agenerate([inputs], run_manager=run_manager)
#     235     return self.create_outputs(response)[0]
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chains/llm.py:116, in LLMChain.agenerate(self, input_list, run_manager)
#     114 """Generate LLM result from inputs."""
#     115 prompts, stop = await self.aprep_prompts(input_list, run_manager=run_manager)
# --> 116 return await self.llm.agenerate_prompt(
#     117     prompts,
#     118     stop,
#     119     callbacks=run_manager.get_child() if run_manager else None,
#     120     **self.llm_kwargs,
#     121 )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/base.py:177, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     169 async def agenerate_prompt(
#     170     self,
#     171     prompts: List[PromptValue],
#    (...)
#     174     **kwargs: Any,
#     175 ) -> LLMResult:
#     176     prompt_messages = [p.to_messages() for p in prompts]
# --> 177     return await self.agenerate(
#     178         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     179     )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/base.py:150, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, **kwargs)
#     148 except (KeyboardInterrupt, Exception) as e:
#     149     await run_manager.on_llm_error(e)
# --> 150     raise e
#     151 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#     152 generations = [res.generations for res in results]
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/base.py:140, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, **kwargs)
#     136 new_arg_supported = inspect.signature(self._agenerate).parameters.get(
#     137     "run_manager"
#     138 )
#     139 try:
# --> 140     results = await asyncio.gather(
#     141         *[
#     142             self._agenerate(m, stop=stop, run_manager=run_manager, **kwargs)
#     143             if new_arg_supported
#     144             else self._agenerate(m, stop=stop)
#     145             for m in messages
#     146         ]
#     147     )
#     148 except (KeyboardInterrupt, Exception) as e:
#     149     await run_manager.on_llm_error(e)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/openai.py:419, in ChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#     417     return ChatResult(generations=[ChatGeneration(message=message)])
#     418 else:
# --> 419     response = await acompletion_with_retry(
#     420         self, messages=message_dicts, **params
#     421     )
#     422     return self._create_chat_result(response)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/openai.py:93, in acompletion_with_retry(llm, **kwargs)
#      88 @retry_decorator
#      89 async def _completion_with_retry(**kwargs: Any) -> Any:
#      90     # Use OpenAI's async api https://github.com/openai/openai-python#async-api
#      91     return await llm.client.acreate(**kwargs)
# ---> 93 return await _completion_with_retry(**kwargs)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/tenacity/_asyncio.py:88, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#      86 @functools.wraps(fn)
#      87 async def async_wrapped(*args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 88     return await fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/tenacity/_asyncio.py:47, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      45 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#      46 while True:
# ---> 47     do = self.iter(retry_state=retry_state)
#      48     if isinstance(do, DoAttempt):
#      49         try:
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/tenacity/_asyncio.py:50, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      48 if isinstance(do, DoAttempt):
#      49     try:
# ---> 50         result = await fn(*args, **kwargs)
#      51     except BaseException:  # noqa: B902
#      52         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/langchain/chat_models/openai.py:91, in acompletion_with_retry.<locals>._completion_with_retry(**kwargs)
#      88 @retry_decorator
#      89 async def _completion_with_retry(**kwargs: Any) -> Any:
#      90     # Use OpenAI's async api https://github.com/openai/openai-python#async-api
# ---> 91     return await llm.client.acreate(**kwargs)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:45, in ChatCompletion.acreate(cls, *args, **kwargs)
#      43 while True:
#      44     try:
# ---> 45         return await super().acreate(*args, **kwargs)
#      46     except TryAgain as e:
#      47         if timeout is not None and time.time() > start + timeout:
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:217, in EngineAPIResource.acreate(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     192 @classmethod
#     193 async def acreate(
#     194     cls,
#    (...)
#     201     **params,
#     202 ):
#     203     (
#     204         deployment_id,
#     205         engine,
#    (...)
#     215         api_key, api_base, api_type, api_version, organization, **params
#     216     )
# --> 217     response, _, api_key = await requestor.arequest(
#     218         "post",
#     219         url,
#     220         params=params,
#     221         headers=headers,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     227     if stream:
#     228         # must be an iterator
#     229         assert not isinstance(response, OpenAIResponse)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openai/api_requestor.py:310, in APIRequestor.arequest(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     299 try:
#     300     result = await self.arequest_raw(
#     301         method.lower(),
#     302         url,
#    (...)
#     308         request_timeout=request_timeout,
#     309     )
# --> 310     resp, got_stream = await self._interpret_async_response(result, stream)
#     311 except Exception:
#     312     await ctx.__aexit__(None, None, None)
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openai/api_requestor.py:646, in APIRequestor._interpret_async_response(self, result, stream)
#     643 except aiohttp.ClientError as e:
#     644     util.log_warn(e, body=result.content)
#     645 return (
# --> 646     self._interpret_response_line(
#     647         (await result.read()).decode("utf-8"),
#     648         result.status,
#     649         result.headers,
#     650         stream=False,
#     651     ),
#     652     False,
#     653 )
#
# File ~/.pyenv/versions/3.10.10/lib/python3.10/site-packages/openai/api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681 stream_error = stream and "error" in resp.data
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# InvalidRequestError: This model's maximum context length is 4097 tokens. However, your messages resulted in 4199 tokens. Please reduce the length of the messages.
